# %%
import csv
import imp
import random
import time
import pandas as pd
from icecream import ic
from selenium import webdriver

#  Instantiate browser objects
driver = webdriver.Chrome(executable_path="./Driver/chromedriver.exe")
#  Open the url
jobphp = []
for i in range(1,11):
    driver.get('https://www.zhipin.com/c100010000/?query=php&page='+str(i)+'&ka=page-'+str(i)+'')
    #  Wait for the page to load
    driver.implicitly_wait(10)
    #  Get data content
    lis = driver.find_elements_by_css_selector('.job-list ul li')
    #  Get multiple li Label plus s
    for li in lis:
        title = li.find_element_by_css_selector('.job-area-wrapper span').text
        salary = li.find_element_by_css_selector('.job-limit.clearfix span').text
        cop_name = li.find_element_by_css_selector('.name a').text
        cop_info = li.find_element_by_css_selector('.company-text p').text
        exprence = li.find_element_by_css_selector('.job-limit.clearfix p').text
        tags = li.find_element_by_css_selector('.tags span').text
        welfare = li.find_element_by_css_selector('.info-desc').text
        jobphp_info = [title,salary,cop_name, cop_info,exprence,tags,welfare]
        jobphp.append(jobphp_info)
    time.sleep(10)
# Out:
# C:\Users\tuannghia\AppData\Local\Temp\ipykernel_1164\122329473.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="./Driver/chromedriver.exe")
# C:\Users\tuannghia\AppData\Local\Temp\ipykernel_1164\122329473.py:18: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   lis = driver.find_elements_by_css_selector('.job-list ul li')
# c:\Users\tuannghia\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:484: UserWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   warnings.warn("find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead")

# %%
dfphp = pd.DataFrame(jobphp)
columns = ['title' ,'salary', 'cop_name' ,'cop_info' ,'exprence', 'tags' ,'welfare', 'job_info' ] 
dfphp.rename(columns=dict(enumerate(columns)),inplace=True)

# %%
dfphp
# Out:
#             title      salary    cop_name          cop_info   exprence   tags  \
# 0             葫芦岛    50-80元/天       冒险者科技    计算机服务未融资20-99人  5天/周5个月本科  Linux
# 1       苏州·相城区·元和      11-20K         笑拼购  批发/零售未融资500-999人     1-3年大专  Linux
# 2      深圳·南山区·科技园  13-20K·13薪        金龄科技     互联网A轮100-499人     3-5年本科  MySQL
# 3    大连·甘井子区·高新园区       8-13K  比特信息技术服务中心   电子商务未融资100-499人   3-5年学历不限    php
# 4              阜阳        4-8K        米乐科技   计算机服务不需要融资0-20人     1-3年本科    php
# ..            ...         ...         ...               ...        ...    ...
# 273    银川·西夏区·西花园       5-10K      炬点品牌集团   互联网B轮1000-9999人     1-3年本科    PHP
# 274    上海·徐汇区·漕河泾      12-24K       喜游戏科技       游戏未融资20-99人     3-5年大专    PHP
# 275    昆明·官渡区·经开区        2-3K        重置科技       互联网未融资0-20人     1-3年本科    PHP
# 276   徐州·云龙区·世茂广场        5-9K        溪谷软件    计算机软件未融资20-99人   经验不限学历不限  Web前端
# 277     佛山·顺德区·大良        4-8K        翔达科技       互联网未融资0-20人     1-3年大专    PHP
#
#                                                welfare
# 0                                      节日福利，零食下午茶，五险一金
# 1       加班补助，餐补，节日福利，年终奖，定期体检，五险一金，股票期权，员工旅游，带薪年假，免费班车
# 2     股票期权，年终奖，带薪年假，加薪晋升，一档医保，户外团建，节日福利，零食下午茶，全勤奖，五险一金
# 3    交通补助，员工旅游，免费班车，年终奖，带薪年假，定期体检，五险一金，补充医疗保险，节日福利，...
# 4                               年终奖，员工旅游，全勤奖，加班补助，带薪年假
# ..                                                 ...
# 273                   五险一金，员工旅游，交通补助，带薪年假，餐补，加班补助，节日福利
# 274                交通补助，补充医疗保险，零食下午茶，五险一金，带薪年假，餐补，加班补助
# 275
# 276     零食下午茶，股票期权，员工旅游，节日福利，带薪年假，五险一金，全勤奖，交通补助，包吃，年终奖
# 277                                           年终奖，带薪年假
#
# [278 rows x 7 columns]

# %%
dfphp.to_excel("php.xlsx")
