# %%
import pandas as pd
import numpy as np

# %%
dfc =   pd.read_excel("c.xlsx")
dfgo = pd.read_excel("golang.xlsx")
dfjava = pd.read_excel("java.xlsx")
dfphp = pd.read_excel("php.xlsx")
dfpy = pd.read_excel("python.xlsx")

# %%
pd.concat([dfc,dfphp],axis=0)
# Out:
#      Unnamed: 0                                              title  \
# 0             0                   Shanghai Xuhui District Xujiahui
# 1             1                  Shanghai Pudong New Area Lujiazui
# 2             2                                             Dalian
# 3             3          Beijing, Haidian District, Northwest Wang
# 4             4                     Shanghai·Yangpu District·Yanji
# ..          ...                                                ...
# 273         273                Yinchuan·Xixia District·West Garden
# 274         274                Shanghai, Xuhui District, Caohejing
# 275         275   Kunming · Guandu District · Economic Developm...
# 276         276               Xuzhou·Yunlong District·Shimao Plaza
# 277         277                     Foshan Shunde District Daliang
#
#                 salary                      cop_name  \
# 0               15-25K              Micro Technology
# ...

# %%
dfjava.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  262 non-null    int64
#  1   title       262 non-null    object
#  2   salary      262 non-null    object
#  3   cop_name    262 non-null    object
#  4   cop_info    262 non-null    object
#  5   exprence    262 non-null    object
#  6   tags        262 non-null    object
#  7   welfare     226 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 16.5+ KB

# %%
data = pd.concat([dfc, dfgo,dfpy,dfphp],axis=0)

# %%
data = data.drop(['index'],axis=1)

# %%
data
# Out:
#                                                   title             salary  \
# 0                      Shanghai Xuhui District Xujiahui             15-25K
# 1                     Shanghai Pudong New Area Lujiazui             16-25K
# 2                                                Dalian             10-15K
# 3             Beijing, Haidian District, Northwest Wang   20-35K 15 salary
# 4                        Shanghai·Yangpu District·Yanji   50-60K 18 salary
# ...                                                 ...                ...
# 1153                Yinchuan·Xixia District·West Garden              5-10K
# 1154                Shanghai, Xuhui District, Caohejing             12-24K
# 1155   Kunming · Guandu District · Economic Developm...               2-3K
# 1156               Xuzhou·Yunlong District·Shimao Plaza               5-9K
# 1157                     Foshan Shunde District Daliang               4-8K
#
#                           cop_name  \
# ...

# %%
data.to_csv("data.csv")
